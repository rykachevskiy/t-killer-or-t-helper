# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

from tqdm import tqdm

import pickle

# %%
cdr1_ref = pd.read_table("../data_all_CDR/TRBV_aaCDR1_func.tsv", names = ["name", "seq"])
cdr2_ref = pd.read_table("../data_all_CDR/TRBV_aaCDR2_func.tsv", names = ["name", "seq"])

# %%
cdr1_ref
# Out:
#         name     seq
# 0    TRBV6-3   MNHEY
# 1    TRBV7-6   SGHVS
# 2    TRBV3-1   LGHDT
# 3     TRBV15   LNHNV
# 4   TRBV11-3   SGHNT
# 5    TRBV5-4   SGHNT
# 6     TRBV19   LNHDA
# 7    TRBV4-1   MGHRA
# 8   TRBV10-3   ENHRY
# 9     TRBV28   MDHEN
# 10     TRBV2   SNHLY
# 11   TRBV6-6   MNHNY
# 12   TRBV7-9   SEHNR
# 13  TRBV11-2   SGHAT
# 14  TRBV29-1   SQVTM
# 15   TRBV5-1   SGHRS
# 16   TRBV5-8   SGHTS
# 17   TRBV4-2   LGHNA
# 18     TRBV9   SGDLS
# 19   TRBV7-2   SGHTA
# 20    TRBV27   MNHEY
# 21  TRBV20-1  DFQATT
# 22  TRBV12-5   LGHNT
# 23  TRBV12-4   SGHDY
# 24   TRBV6-1   MNHNS
# 25   TRBV7-8   SGHVS
# 26  TRBV25-1   MGHDK
# 27    TRBV13   PRHDT
# 28  TRBV11-1   SGHAT
# 29   TRBV5-5   SGHKS
# 30   TRBV4-3   LGHNA
# 31   TRBV6-4   MRHNA
# 32   TRBV6-8   MNHGY
# 33  TRBV12-3   SGHNS
# 34   TRBV7-7   SSHAT
# 35   TRBV7-3   SGHTA
# 36    TRBV18   KGHSH
# 37  TRBV24-1   KGHDR
# 38    TRBV14   SGHDN
# 39   TRBV5-6   SGHDT
# 40  TRBV10-2   WSHSY
# 41   TRBV6-5   MNHEY
# ...
